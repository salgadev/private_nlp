# %% [markdown]
# # Plotting Loss and Accuracy Results data

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt

# %%
acc_df = pd.read_csv("fig_data/acc_data.csv")

# %%
acc_df
# Out:
#      Iteration  Accuracy       Event
# 0            1  34.37500    Training
# 1            2  29.68750    Training
# 2            3  66.40625    Training
# 3            4  69.53125    Training
# 4            5  65.62500    Training
# ..         ...       ...         ...
# 169         83  78.90625  Validation
# 170         84  82.03125  Validation
# 171         85  80.46875  Validation
# 172         86  77.34375  Validation
# 173         87  83.59375  Validation
#
# [174 rows x 3 columns]

# %%
sns.set(rc={'figure.figsize':(12, 6)})
ax = sns.lineplot(x="Iteration", y="Accuracy", hue="Event",
                  err_style="bars", ci=68, data=acc_df)

# %%
loss_df = pd.read_csv("fig_data/loss_data.csv")

# %%
loss_df
# Out:
#           Event  Iteration        Loss
# 0      Training          1  126.720001
# 1      Training          2  110.152000
# 2      Training          3   69.777000
# 3      Training          4   54.783001
# 4      Training          5   58.301998
# ..          ...        ...         ...
# 170  Validation         83   34.291000
# 171  Validation         84   27.499001
# 172  Validation         85   30.577999
# 173  Validation         86   36.158001
# 174  Validation         87   30.282000
#
# [175 rows x 3 columns]

# %%
sns.set(rc={'figure.figsize':(12, 6)})
ax = sns.lineplot(x="Iteration", y="Loss", hue="Event",
                  err_style="bars", ci=68, data=loss_df)
